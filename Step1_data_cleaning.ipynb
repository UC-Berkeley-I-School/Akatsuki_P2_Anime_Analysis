# %% [markdown]
# ## GROUP 4 Project 2 AnimeList Analysis

# %% [markdown]
# ###  Step 1: Data Cleaning

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#paths are relative paths, please don't run cell if you don't have the data downloaded
pre_2020 = pd.read_csv('data/anime_pre2020.csv', index_col=False)
post_2020 = pd.read_csv('data/anime_main.csv', index_col=False)

# %%
pre_2020.shape
# Out:
# (19311, 12)

# %%
#drop duplicates
pre_2020 = pre_2020.drop_duplicates()
pre_2020.shape
# Out:
# (16368, 12)

# %%
pre_2020.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...

# %%
post_2020.shape
# Out:
# (20741, 35)

# %%
post_2020 = post_2020.drop_duplicates()
post_2020.shape
# Out:
# (20741, 35)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(post_2020.head())
# Out:
#    mal_id                               title   type  score  scored_by  \
# 0    5114    Fullmetal Alchemist: Brotherhood     TV   9.13    1865027
# 1   11061              Hunter x Hunter (2011)     TV   9.05    1502709
# 2   38524  Shingeki no Kyojin Season 3 Part 2     TV   9.07    1322101
# 3    9253                         Steins;Gate     TV   9.08    1248451
# 4   28851                      Koe no Katachi  Movie   8.95    1392476
#
#             status  episodes airing_from   airing_to        source  members  \
# 0  Finished Airing      64.0  2009-04-05  2010-07-04         Manga  2922030
# 1  Finished Airing     148.0  2011-10-02  2014-09-24         Manga  2408403
# 2  Finished Airing      10.0  2019-04-29  2019-07-01         Manga  1871324
# 3  Finished Airing      24.0  2011-04-06  2011-09-14  Visual novel  2262118
# 4  Finished Airing       1.0  2016-09-17  2016-09-17         Manga  1992945
#
#    favorites episode_duration                          rating   sfw  \
# 0     204080  0 days 00:24:20  R - 17+ (violence & profanity)  True
# 1     184415  0 days 00:23:37       PG-13 - Teens 13 or older  True
# 2      51754  0 days 00:23:55  R - 17+ (violence & profanity)  True
# 3     172591  0 days 00:24:20       PG-13 - Teens 13 or older  True
# 4      77132  0 days 02:10:03       PG-13 - Teens 13 or older  True
#
#    start_year start_season broadcast_day broadcast_time  \
# 0      2009.0       spring        sunday       17:00:00
# 1      2011.0         fall        sunday       10:55:00
# 2      2019.0       spring        monday       00:10:00
# 3      2011.0       spring     wednesday       02:05:00
# 4      2016.0       summer           NaN            NaN
#
#                                         genres  \
# 0  ['Action', 'Adventure', 'Drama', 'Fantasy']
# 1           ['Action', 'Adventure', 'Fantasy']
# 2                          ['Action', 'Drama']
# 3              ['Drama', 'Sci-Fi', 'Suspense']
# 4                                    ['Drama']
#
#                              themes demographics              studios  \
# 0                      ['Military']  ['Shounen']            ['Bones']
# 1                                []  ['Shounen']         ['Madhouse']
# 2  ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 3  ['Psychological', 'Time Travel']           []        ['White Fox']
# 4              ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Movic', '...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' re...
# 4  Winner of the Excellence Award on the 20th Jap...
#
#               mal_created_at             mal_updated_at  \
# 0  2008-08-21 03:35:22+00:00  2022-04-18 05:06:13+00:00
# 1  2011-07-27 08:41:39+00:00  2022-04-18 05:11:21+00:00
# 2  2018-10-14 18:13:45+00:00  2022-04-18 05:02:23+00:00
# 3  2010-07-26 09:23:40+00:00  2022-05-01 21:24:42+00:00
# 4  2014-12-15 08:00:46+00:00  2022-04-18 04:55:56+00:00
#
#                                          picture_url  \
# 0  https://api-cdn.myanimelist.net/images/anime/1...
# 1  https://api-cdn.myanimelist.net/images/anime/1...
# 2  https://api-cdn.myanimelist.net/images/anime/1...
# 3  https://api-cdn.myanimelist.net/images/anime/5...
# 4  https://api-cdn.myanimelist.net/images/anime/1...
#
#                                              mal_url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']

# %%
#joining pre-covid data to post covid data. validate id and name are unique to each other
pre_2020.groupby(['uid','title']).count().head(20)['synopsis']
# Out:
# uid  title
# 1    Cowboy Bebop                       1
# 5    Cowboy Bebop: Tengoku no Tobira    1
# 6    Trigun                             1
# 7    Witch Hunter Robin                 1
# 8    Bouken Ou Beet                     1
# 15   Eyeshield 21                       1
# 16   Hachimitsu to Clover               1
# 17   Hungry Heart: Wild Striker         1
# 18   Initial D Fourth Stage             1
# 19   Monster                            1
# 20   Naruto                             1
# 21   One Piece                          1
# 22   Tennis no Ouji-sama                1
# 23   Ring ni Kakero 1                   1
# 24   School Rumble                      1
# 25   Sunabouzu                          1
# 26   Texhnolyze                         2
# 27   Trinity Blood                      1
# 28   Yakitate!! Japan                   1
# 29   Zipang                             1
# Name: synopsis, dtype: int64

# %%
post_2020.groupby(['mal_id','title']).count().head(20)['synopsis']
# Out:
# mal_id  title
# 1       Cowboy Bebop                       1
# 5       Cowboy Bebop: Tengoku no Tobira    1
# 6       Trigun                             1
# 7       Witch Hunter Robin                 1
# 8       Bouken Ou Beet                     1
# 15      Eyeshield 21                       1
# 16      Hachimitsu to Clover               1
# 17      Hungry Heart: Wild Striker         1
# 18      Initial D Fourth Stage             1
# 19      Monster                            1
# 20      Naruto                             1
# 21      One Piece                          1
# 22      Tennis no Ouji-sama                1
# 23      Ring ni Kakero 1                   1
# 24      School Rumble                      1
# 25      Sunabouzu                          1
# 26      Texhnolyze                         1
# 27      Trinity Blood                      1
# 28      Yakitate!! Japan                   1
# 29      Zipang                             1
# Name: synopsis, dtype: int64

# %%
#with validation, id and nanme are unique to each other. Considering more anime aired in 2022, we will be joining the 2020 data to 2022data. 
anime_merge = pd.merge(post_2020, pre_2020, 
                      left_on=  ['mal_id','title'],
                       right_on= ['uid','title'], 
                       how = 'left')

# %%
#cleaning column names
anime_merge.columns
# Out:
# Index(['mal_id', 'title', 'type', 'score_x', 'scored_by', 'status',
#        'episodes_x', 'airing_from', 'airing_to', 'source', 'members_x',
#        'favorites', 'episode_duration', 'rating', 'sfw', 'start_year',
#        'start_season', 'broadcast_day', 'broadcast_time', 'genres', 'themes',
#        'demographics', 'studios', 'producers', 'licensors', 'synopsis_x',
#        'background', 'mal_created_at', 'mal_updated_at', 'picture_url',
#        'mal_url', 'trailer_url', 'title_english', 'title_japanese',
#        'title_synonyms', 'uid', 'synopsis_y', 'genre', 'aired', 'episodes_y',
#        'members_y', 'popularity', 'ranked', 'score_y', 'img_url', 'link'],
#       dtype='object')

# %%
new_name_dict = {'mal_id':'id_2022', 
                 'title': 'title', 
                 'type': 'type', 
                 'score_x': 'score_2022', 
                 'scored_by': 'scored_by_2022', 
                 'status': 'status',
                 'episodes_x': 'episodes_2022', 
                 'airing_from': 'airing_from', 
                 'airing_to': 'airing_to', 
                 'source': 'source', 
                 'members_x': 'members_2022',
                 'favorites': 'favorites_2022', 
                 'episode_duration': 'episode_duration', 
                 'rating': 'pg_rating', 
                 'sfw': 'sfw', 
                 'start_year': 'start_year',
                 'start_season': 'start_season', 
                 'broadcast_day': 'broadcast_day', 
                 'broadcast_time': 'broadcast_time', 
                 'genres' : 'genres', 
                 'themes': 'themes',
                 'demographics': 'demographics', 
                 'studios': 'studios', 
                 'producers': 'producers', 
                 'licensors': 'licensors', 
                 'synopsis_x': 'synopsis_2022',
                 'background': 'background', 
                 'mal_created_at': 'mal_created_at', 
                 'mal_updated_at': 'mal_updated_at', 
                 'picture_url': 'picture_url',
                 'mal_url' : 'mal_url', 
                 'trailer_url': 'trailer_url', 
                 'title_english': 'title_english', 
                 'title_japanese': 'title_japanese',
                 'title_synonyms': 'title_synonyms', 
                 'uid' : 'id_2020', 
                 'synopsis_y' :'synopsis_2020', 
                 'genre': 'genre', 
                 'aired': 'aired', 
                 'episodes_y': 'episodes_2020',
                 'members_y' : 'members_2020', 
                 'popularity' : 'popularity_2020', 
                 'ranked': 'ranked_2020', 
                 'score_y' : 'score_2020', 
                 'img_url' : 'img_url', 
                 'link': 'link'}

# %%
anime_merge = anime_merge.rename(columns=new_name_dict)

# %%
anime_merge.head(10)
# Out:
#    id_2022                                 title   type  score_2022  \
# 0     5114      Fullmetal Alchemist: Brotherhood     TV        9.13
# 1    11061                Hunter x Hunter (2011)     TV        9.05
# 2    38524    Shingeki no Kyojin Season 3 Part 2     TV        9.07
# 3     9253                           Steins;Gate     TV        9.08
# 4    28851                        Koe no Katachi  Movie        8.95
# 5    32281                        Kimi no Na wa.  Movie        8.86
# 6     2904    Code Geass: Hangyaku no Lelouch R2     TV        8.91
# 7    40028  Shingeki no Kyojin: The Final Season     TV        8.84
# 8      199         Sen to Chihiro no Kamikakushi  Movie        8.78
# 9     1575       Code Geass: Hangyaku no Lelouch     TV        8.70
#
#    scored_by_2022           status  episodes_2022 airing_from   airing_to  \
# 0         1865027  Finished Airing           64.0  2009-04-05  2010-07-04
# 1         1502709  Finished Airing          148.0  2011-10-02  2014-09-24
# 2         1322101  Finished Airing           10.0  2019-04-29  2019-07-01
# 3         1248451  Finished Airing           24.0  2011-04-06  2011-09-14
# 4         1392476  Finished Airing            1.0  2016-09-17  2016-09-17
# 5         1669497  Finished Airing            1.0  2016-08-26  2016-08-26
# 6         1076510  Finished Airing           25.0  2008-04-06  2008-09-28
# 7         1073027  Finished Airing           16.0  2020-12-07  2021-03-29
# 8         1145304  Finished Airing            1.0  2001-07-20  2001-07-20
# 9         1262624  Finished Airing           25.0  2006-10-06  2007-07-29
#
#          source  ...                                      synopsis_2020  \
# 0         Manga  ...  "In order for something to be obtained, someth...
# 1         Manga  ...  Hunter x Hunter  is set in a world where Hunte...
# 2         Manga  ...  Seeking to restore humanity’s diminishing hope...
# 3  Visual novel  ...  The self-proclaimed mad scientist Rintarou Oka...
# 4         Manga  ...  As a wild youth, elementary school student Sho...
# 5      Original  ...  Mitsuha Miyamizu, a high school girl, yearns t...
# 6      Original  ...  One year has passed since the Black Rebellion,...
# 7         Manga  ...                                                NaN
# 8      Original  ...  Stubborn, spoiled, and naïve, 10-year-old Chih...
# 9      Original  ...  In the year 2010, the Holy Empire of Britannia...
#
#                                                genre  \
# 0  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 1  ['Action', 'Adventure', 'Fantasy', 'Shounen', ...
# 2  ['Action', 'Drama', 'Fantasy', 'Military', 'My...
# 3                             ['Thriller', 'Sci-Fi']
# 4                     ['Drama', 'School', 'Shounen']
# 5     ['Romance', 'Supernatural', 'School', 'Drama']
# 6  ['Action', 'Military', 'Sci-Fi', 'Super Power'...
# 7                                                NaN
# 8             ['Adventure', 'Supernatural', 'Drama']
# 9  ['Action', 'Military', 'Sci-Fi', 'Super Power'...
#
#                          aired episodes_2020  members_2020  popularity_2020  \
# 0   Apr 5, 2009 to Jul 4, 2010          64.0     1615084.0              4.0
# 1  Oct 2, 2011 to Sep 24, 2014         148.0     1052761.0             20.0
# 2  Apr 29, 2019 to Jul 1, 2019          10.0      446370.0            175.0
# 3  Apr 6, 2011 to Sep 14, 2011          24.0     1331710.0              7.0
# 4                 Sep 17, 2016           1.0      842277.0             53.0
# 5                 Aug 26, 2016           1.0     1139878.0             15.0
# 6  Apr 6, 2008 to Sep 28, 2008          25.0      992196.0             27.0
# 7                          NaN           NaN           NaN              NaN
# 8                 Jul 20, 2001           1.0      913212.0             40.0
# 9  Oct 6, 2006 to Jul 29, 2007          25.0     1231546.0             11.0
#
#   ranked_2020 score_2020                                            img_url  \
# 0         1.0       9.23  https://cdn.myanimelist.net/images/anime/1223/...
# 1         3.0       9.11  https://cdn.myanimelist.net/images/anime/11/33...
# 2         5.0       9.07  https://cdn.myanimelist.net/images/anime/1517/...
# 3         2.0       9.11  https://cdn.myanimelist.net/images/anime/5/731...
# 4        10.0       9.01  https://cdn.myanimelist.net/images/anime/1122/...
# 5         4.0       9.09  https://cdn.myanimelist.net/images/anime/5/870...
# 6        17.0       8.93  https://cdn.myanimelist.net/images/anime/4/939...
# 7         NaN        NaN                                                NaN
# 8        20.0       8.90  https://cdn.myanimelist.net/images/anime/6/795...
# 9        31.0       8.76  https://cdn.myanimelist.net/images/anime/5/503...
#
#                                                 link
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
# 5  https://myanimelist.net/anime/32281/Kimi_no_Na_wa
# 6  https://myanimelist.net/anime/2904/Code_Geass_...
# 7                                                NaN
# 8  https://myanimelist.net/anime/199/Sen_to_Chihi...
# 9  https://myanimelist.net/anime/1575/Code_Geass_...
#
# [10 rows x 46 columns]

# %%
#creating master data file
anime_merge.to_csv('data/anime_master_data.csv', index = False)

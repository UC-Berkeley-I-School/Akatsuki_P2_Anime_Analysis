# %%
import pandas as pd
df = pd.read_csv('text_cleaning.csv')
df
# Out:
#       id_2022                           title_english   type  score_2022  \
# 0       38524         attack on titan season 3 part 2     tv        9.07
# 1        9253                              steinsgate     tv        9.08
# 2       28851                          a silent voice  movie        8.95
# 3       32281                               your name  movie        8.86
# 4        2904  code geass lelouch of the rebellion r2     tv        8.91
# ...       ...                                     ...    ...         ...
# 1069    29371                         naccio and pomm     tv         NaN
# 1070    33078                      monsieur greenpeas  movie         NaN
# 1071    33320                             datum point  movie         NaN
# 1072    35799                               miniforce     tv         NaN
# 1073    34717                           laughing moon  movie         NaN
#
#       scored_by_2022           status  episodes_2022        source  \
# ...

# %%
df.columns
# Out:
# Index(['id_2022', 'title', 'type', 'score_2022', 'scored_by_2022', 'status',
#        'episodes_2022', 'source', 'members_2022', 'favorites_2022',
#        'episode_duration', 'pg_rating', 'sfw', 'genres_2022', 'themes',
#        'demographics', 'synopsis_2022', 'background', 'id_2020',
#        'synopsis_2020', 'genre_2020', 'aired', 'episodes_2020', 'members_2020',
#        'popularity_2020', 'ranked_2020', 'score_2020'],
#       dtype='object')

# %%
df.sort_values(by = 'score_2022', ascending = False).head(5)
# Out:
#      id_2022                    title_english type  score_2022  \
# 1       9253                       steinsgate   tv        9.08
# 64     28977                 gintama season 4   tv        9.08
# 0      38524  attack on titan season 3 part 2   tv        9.07
# 71      9969                 gintama season 2   tv        9.05
# 104    15417                gintama enchousen   tv        9.04
#
#      scored_by_2022           status  episodes_2022        source  \
# 1           1248451  finished airing           24.0  visual novel
# 64           217787  finished airing           51.0         manga
# 0           1322101  finished airing           10.0         manga
# 71           209856  finished airing           51.0         manga
# 104          146612  finished airing           13.0         manga
#
#      members_2022  favorites_2022  ...  \
# 1         2262118          172591  ...
# 64         542861           14616  ...
# 0         1871324           51754  ...
# ...

# %%
df.sort_values(by = 'episodes_2022', ascending = False).head(5)
# Out:
#      id_2022  title_english type  score_2022  scored_by_2022           status  \
# 126      269         bleach   tv        7.86          976626  finished airing
# 625      508        hamtaro   tv        6.98           27367  finished airing
# 70       813  dragon ball z   tv        8.15          768495  finished airing
# 96        20         naruto   tv        7.97         1751841  finished airing
# 777    19157    yokai watch   tv        6.54           12465  finished airing
#
#      episodes_2022 source  members_2022  favorites_2022  ...  \
# 126          366.0  manga       1673291           60489  ...
# 625          296.0  manga         54164             238  ...
# 70           291.0  manga       1103459           33276  ...
# 96           220.0  manga       2510293           70509  ...
# 777          214.0   game         27239             192  ...
#
#                                             background  id_2020  \
# ...

# %%
df.sort_values(by = 'score_2020', ascending = False).head(5)
# Out:
#     id_2022                    title_english   type  score_2022  \
# 1      9253                       steinsgate     tv        9.08
# 3     32281                        your name  movie        8.86
# 0     38524  attack on titan season 3 part 2     tv        9.07
# 64    28977                 gintama season 4     tv        9.08
# 71     9969                 gintama season 2     tv        9.05
#
#     scored_by_2022           status  episodes_2022        source  \
# 1          1248451  finished airing           24.0  visual novel
# 3          1669497  finished airing            1.0      original
# 0          1322101  finished airing           10.0         manga
# 64          217787  finished airing           51.0         manga
# 71          209856  finished airing           51.0         manga
#
#     members_2022  favorites_2022  ...  \
# 1        2262118          172591  ...
# 3        2383752           82278  ...
# 0        1871324           51754  ...
# ...

# %%
df.sort_values(by = 'ranked_2020', ascending = False).head(5)
# Out:
#       id_2022                 title_english   type  score_2022  \
# 1003    40238            dream into drawing  movie        6.02
# 1048    34946                the snow queen  movie         NaN
# 1055    38069      brinken skate revolution     tv         NaN
# 994     37300  the adventure of little carp     tv        6.12
# 1073    34717                 laughing moon  movie         NaN
#
#       scored_by_2022           status  episodes_2022    source  members_2022  \
# 1003             119  finished airing            1.0     novel           473
# 1048              91  finished airing            1.0      book           304
# 1055              81  finished airing           40.0  original           244
# 994              124  finished airing           52.0     other           306
# 1073              40  finished airing            1.0  original           130
#
#       favorites_2022  ...                                         background  \
# ...

# %%
df.sort_values(by = 'members_2020', ascending = False).head(5)
# Out:
#     id_2022    title_english type  score_2022  scored_by_2022  \
# 7      1535       death note   tv        8.62         2442650
# 13    16498  attack on titan   tv        8.53         2475800
# 15    30276    one punch man   tv        8.51         1982244
# 1      9253       steinsgate   tv        9.08         1248451
# 69    19815  no game no life   tv        8.10         1409303
#
#              status  episodes_2022        source  members_2022  \
# 7   finished airing           37.0         manga       3443330
# 13  finished airing           25.0         manga       3461461
# 15  finished airing           12.0     web manga       2827135
# 1   finished airing           24.0  visual novel       2262118
# 69  finished airing           12.0   light novel       2170933
#
#     favorites_2022  ...                                         background  \
# 7           156956  ...  death note ha been adapted into live action fi...
# ...

# %%
df.sort_values(by = 'popularity_2020', ascending = False).head(5)
# Out:
#       id_2022                                      title_english   type  \
# 301     40540  sword art online alicization war of underworld...     tv
# 730     40960  drug store in another world the slow life of a...     tv
# 1072    35799                                          miniforce     tv
# 1054    38729                                         piercing i  movie
# 1058    39781                             keep calm and carry on    ona
#
#       score_2022  scored_by_2022           status  episodes_2022       source  \
# 301         7.46          291771  finished airing           11.0  light novel
# 730         6.49           41352  finished airing           12.0  light novel
# 1072         NaN              47  finished airing           52.0     original
# 1054         NaN              44  finished airing            1.0     original
# 1058         NaN              93  finished airing            1.0        other
#
#       members_2022  favorites_2022  ...  \
# ...

# %%
df.columns
# Out:
# Index(['id_2022', 'title_english', 'type', 'score_2022', 'scored_by_2022',
#        'status', 'episodes_2022', 'source', 'members_2022', 'favorites_2022',
#        'episode_duration', 'pg_rating', 'sfw', 'genres_2022', 'themes',
#        'demographics', 'synopsis_2022', 'background', 'id_2020',
#        'synopsis_2020', 'genre_2020', 'aired', 'episodes_2020', 'members_2020',
#        'popularity_2020', 'ranked_2020', 'score_2020'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.boxplot(y = 'score_2022', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='score_2022'>

# %%
sns.boxplot(y = 'score_2020', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='score_2020'>

# %%
sns.boxplot(y = 'episodes_2022', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='episodes_2022'>

# %%
sns.boxplot(y = 'episodes_2020', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='episodes_2020'>

# %%
sns.boxplot(y = 'members_2022', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='members_2022'>

# %%
sns.boxplot(y = 'members_2020', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='members_2020'>

# %%
sns.boxplot(y = 'popularity_2020', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='popularity_2020'>

# %%
sns.boxplot(y = 'favorites_2022', x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='favorites_2022'>

# %%
sns.scatterplot(data = df, x = 'episodes_2020', y = 'ranked_2020')
# Out:
# <AxesSubplot:xlabel='episodes_2020', ylabel='ranked_2020'>

# %%
sns.scatterplot(data = df, x = 'popularity_2020', y = 'ranked_2020')
# Out:
# <AxesSubplot:xlabel='popularity_2020', ylabel='ranked_2020'>

# %%
sns.scatterplot(data = df, x = 'favorites_2022', y = 'ranked_2020')
# Out:
# <AxesSubplot:xlabel='favorites_2022', ylabel='ranked_2020'>

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
df.columns
# Out:
# Index(['id_2022', 'title_english', 'type', 'score_2022', 'scored_by_2022',
#        'status', 'episodes_2022', 'source', 'members_2022', 'favorites_2022',
#        'episode_duration', 'pg_rating', 'sfw', 'genres_2022', 'themes',
#        'demographics', 'synopsis_2022', 'background', 'id_2020',
#        'synopsis_2020', 'genre_2020', 'aired', 'episodes_2020', 'members_2020',
#        'popularity_2020', 'ranked_2020', 'score_2020'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.title_english:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.genres_2022:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.genre_2020:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.themes:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.background:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.synopsis_2020:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.synopsis_2022:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
